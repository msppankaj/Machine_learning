# %%
##inporting libraries
import pandas as pd
import numpy as np

# %%
#Create series in pd
ser=pd.Series([1,2,3,4,5,6])
serstr=pd.Series(['suman','ramn','rahul','deepk','kundan'])

# %%
#Create dataframe in pd
df=pd.DataFrame({'name':['suman','ramn','rahul','deepk','kundan'],'roll':[1,2,3,4,5]})

# %%
df
# Out:
#      name  roll
# 0   suman     1
# 1    ramn     2
# 2   rahul     3
# 3   deepk     4
# 4  kundan     5

# %%
#transpose df
df.transpose()
# Out:
#           0     1      2      3       4
# name  suman  ramn  rahul  deepk  kundan
# roll      1     2      3      4       5

# %%
#loading data
df_co2=pd.read_csv(r'C:\Users\Pankaj\Downloads\CO2_emission.csv')

# %%
df_co2.columns
# Out:
# Index(['Model_Year', 'Make', 'Model', 'Vehicle_Class', 'Engine_Size',
#        'Cylinders', 'Transmission', 'Fuel_Consumption_in_City(L/100 km)',
#        'Fuel_Consumption_in_City_Hwy(L/100 km)',
#        'Fuel_Consumption_comb(L/100km)', 'CO2_Emissions', 'Smog_Level'],
#       dtype='object')

# %%
df_co2.shape
# Out:
# (935, 12)

# %%
df_co2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935 entries, 0 to 934
# Data columns (total 12 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Model_Year                              935 non-null    int64
#  1   Make                                    935 non-null    object
#  2   Model                                   935 non-null    object
#  3   Vehicle_Class                           935 non-null    object
#  4   Engine_Size                             935 non-null    float64
#  5   Cylinders                               935 non-null    int64
#  6   Transmission                            935 non-null    object
#  7   Fuel_Consumption_in_City(L/100 km)      935 non-null    float64
#  8   Fuel_Consumption_in_City_Hwy(L/100 km)  935 non-null    float64
#  9   Fuel_Consumption_comb(L/100km)          935 non-null    float64
# ...

# %%
df_co2.describe()
# Out:
#        Model_Year  Engine_Size   Cylinders  \
# count       935.0   935.000000  935.000000
# mean       2021.0     3.214866    5.716578
# std           0.0     1.388513    1.977359
# min        2021.0     1.000000    3.000000
# 25%        2021.0     2.000000    4.000000
# 50%        2021.0     3.000000    6.000000
# 75%        2021.0     4.000000    8.000000
# max        2021.0     8.000000   16.000000
#
#        Fuel_Consumption_in_City(L/100 km)  \
# count                          935.000000
# mean                            12.498610
# std                              3.487271
# min                              4.000000
# 25%                             10.100000
# 50%                             12.000000
# 75%                             14.800000
# max                             30.300000
#
#        Fuel_Consumption_in_City_Hwy(L/100 km)  Fuel_Consumption_comb(L/100km)  \
# count                              935.000000                      935.000000
# ...

# %%
df_co2.head(3)
# Out:
#    Model_Year   Make       Model Vehicle_Class  Engine_Size  Cylinders  \
# 0        2021  Acura         ILX       Compact          2.4          4
# 1        2021  Acura         NSX    Two-seater          3.5          6
# 2        2021  Acura  RDX SH-AWD    SUV: Small          2.0          4
#
#   Transmission  Fuel_Consumption_in_City(L/100 km)  \
# 0          AM8                                 9.9
# 1          AM9                                11.1
# 2         AS10                                11.0
#
#    Fuel_Consumption_in_City_Hwy(L/100 km)  Fuel_Consumption_comb(L/100km)  \
# 0                                     7.0                             8.6
# 1                                    10.8                            11.0
# 2                                     8.6                             9.9
#
#    CO2_Emissions  Smog_Level
# 0            199           3
# 1            256           3
# 2            232           6

# %%
df_co2.tail(2)
# Out:
#      Model_Year   Make        Model  Vehicle_Class  Engine_Size  Cylinders  \
# 933        2021  Volvo  XC90 T5 AWD  SUV: Standard          2.0          4
# 934        2021  Volvo  XC90 T6 AWD  SUV: Standard          2.0          4
#
#     Transmission  Fuel_Consumption_in_City(L/100 km)  \
# 933          AS8                                11.5
# 934          AS8                                12.1
#
#      Fuel_Consumption_in_City_Hwy(L/100 km)  Fuel_Consumption_comb(L/100km)  \
# 933                                     8.4                            10.1
# 934                                     8.5                            10.5
#
#      CO2_Emissions  Smog_Level
# 933            236           5
# 934            245           7

# %%
df_co2.index
# Out:
# RangeIndex(start=0, stop=935, step=1)

# %%
#filtering
fil2=df_co2[df_co2['Cylinders']==4]
fil1=df_co2[(df_co2['Model_Year']==2021) & (df_co2['Make']=='Acura') ]
fil3=df_co2[df_co2['Engine_Size'].isin([2.4,2.0])]

# %%
col9=df_co2.iloc[:,9]
index100=df_co2.iloc[:100,:3]

# %%
df_co2.iloc[:10,2:-6]
# Out:
#                  Model Vehicle_Class  Engine_Size  Cylinders
# 0                  ILX       Compact          2.4          4
# 1                  NSX    Two-seater          3.5          6
# 2           RDX SH-AWD    SUV: Small          2.0          4
# 3    RDX SH-AWD A-SPEC    SUV: Small          2.0          4
# 4           TLX SH-AWD       Compact          2.0          4
# 5    TLX SH-AWD A-SPEC       Compact          2.0          4
# 6               Giulia      Mid-size          2.0          4
# 7           Giulia AWD      Mid-size          2.0          4
# 8  Giulia Quadrifoglio      Mid-size          2.9          6
# 9              Stelvio    SUV: Small          2.0          4

# %%
df_co2.loc[1:10,['Model','Vehicle_Class','Engine_Size','Cylinders']]
# Out:
#                   Model Vehicle_Class  Engine_Size  Cylinders
# 1                   NSX    Two-seater          3.5          6
# 2            RDX SH-AWD    SUV: Small          2.0          4
# 3     RDX SH-AWD A-SPEC    SUV: Small          2.0          4
# 4            TLX SH-AWD       Compact          2.0          4
# 5     TLX SH-AWD A-SPEC       Compact          2.0          4
# 6                Giulia      Mid-size          2.0          4
# 7            Giulia AWD      Mid-size          2.0          4
# 8   Giulia Quadrifoglio      Mid-size          2.9          6
# 9               Stelvio    SUV: Small          2.0          4
# 10          Stelvio AWD    SUV: Small          2.0          4

# %%
gr1=df_co2.groupby(['Model','Vehicle_Class'])['Cylinders'].sum()
gr2=df_co2.groupby('Model')['Cylinders'].sum()

# %%
df_co2.duplicated().sum()
# Out:
# 0

# %%
dupl=df_co2['Make'].drop_duplicates()

# %%
dupl.shape
# Out:
# (38,)

# %%
df_co2[['Make','Model','Cylinders']].groupby(['Model','Make'])['Cylinders'].count()
# Out:
# Model                              Make
# 1500                               Ram     1
# 1500 4X4                           Ram     1
# 1500 4X4 EcoDiesel                 Ram     1
# 1500 4X4 TRX                       Ram     1
# 1500 4X4 eTorque                   Ram     2
#                                           ..
# Yukon XL (Without Stop-Start)      GMC     1
# Yukon XL 4WD                       GMC     3
# Yukon XL 4WD (Without Stop-Start)  GMC     2
# Z4 M40i                            BMW     1
# Z4 sDrive30i                       BMW     1
# Name: Cylinders, Length: 703, dtype: int64

# %%
df_co2.sort_values('Make')
df_co2.sort_values(['Make','Cylinders'])
# Out:
#      Model_Year   Make              Model  Vehicle_Class  Engine_Size  \
# 0          2021  Acura                ILX        Compact          2.4
# 2          2021  Acura         RDX SH-AWD     SUV: Small          2.0
# 3          2021  Acura  RDX SH-AWD A-SPEC     SUV: Small          2.0
# 4          2021  Acura         TLX SH-AWD        Compact          2.0
# 5          2021  Acura  TLX SH-AWD A-SPEC        Compact          2.0
# ..          ...    ...                ...            ...          ...
# 930        2021  Volvo        XC40 T5 AWD     SUV: Small          2.0
# 931        2021  Volvo        XC60 T5 AWD     SUV: Small          2.0
# 932        2021  Volvo        XC60 T6 AWD     SUV: Small          2.0
# 933        2021  Volvo        XC90 T5 AWD  SUV: Standard          2.0
# 934        2021  Volvo        XC90 T6 AWD  SUV: Standard          2.0
#
#      Cylinders Transmission  Fuel_Consumption_in_City(L/100 km)  \
# ...

# %%
#pivot
pvt=pd.pivot_table(df_co2,index='Vehicle_Class',columns='Model',values='Cylinders',aggfunc='sum')

# %%
df_co2.iloc[:10,:3].groupby('Model_Year').sum()
# Out:
#                                                          Make  \
# Model_Year
# 2021        AcuraAcuraAcuraAcuraAcuraAcuraAlfa RomeoAlfa R...
#
#                                                         Model
# Model_Year
# 2021        ILXNSXRDX SH-AWDRDX SH-AWD A-SPECTLX SH-AWDTLX...

# %%
df1

# %%
gh=df.groupby(['JOB_ID'])['SALARY'].mean()
gh.head(10)

# %%
df

# %%
#EDA parts

#df.info()
#df.tail()
#df.head()
#df.index
df.describe()
df.columns

# %%
#df.shape
#df.dtypes
#df.count()
#df['City'].value_counts()
#df['City'].unique()
#df.isnull().sum()

# %%
#Data Manupulations
#Droping and filling values
#df_drop=df.drop('City',axis=1)
#df_drop_multiple=df.drop(['Department','Ageing','Email Address'],axis=1)
#drop_row=df.drop(2,axis=0)
#drop_mul_row=df.drop([1,2],axis=0)

# %%
##Renaming columns
df_rename=df.rename(columns={'City':'CTY','Email Address':'Email'})

# %%
#select columns with specific data types
int_data=df.select_dtypes(include='int')
int_data

# %%
#slicing the datasets
df.iloc[:5,0:5]
df.loc[:5,'City']

# %%
#handling Duplicates
dup_val=df.copy()
rw=dup_val.iloc[:1]
dup_val=dup_val.append(row,ignore_index=true)
dup_val
dup_val[dup_val.duplicated()]
dup_val.drop_duplicates()
df[df['City'].duplicated()].shape

# %%
#selecting specific values and see more value filter

df[df['City']=='NOIDA']

# %% [raw]
# df

# %%
#groupby in pandas
df.groupby('City').agg({'Ageing':'count'})
df.groupby(['City','Asset Number']).agg({'Ageing':'count'})

# %%
df['City'].map({'NOIDA':1,'GURGAON':2})

# %%
df['City'].replace(['NEW DELHI', 'NOIDA'], ["M", "F"])

# %%
#write to data
df_co2.to_excel(r'C:\Users\Pankaj\Downloads\kkkjjk.xlsx')

# %%
df_co2['Vehicle_Class']=df_co2['Vehicle_Class'].str.split(":").str.get(1)
df_co2['Vehicle_Class']=df_co2['Vehicle_Class'].str.split(":").str.contains('make')

# %%
df_co2['Make'].value_counts()
df_co2['Make1']=df_co2['Make'].replace({'Ford':'f','Chevrolet':'c'})
df_co2['Make2']=df_co2['Make'].replace({'Porsche':'p','BMW':'b'})

# %%
df_co2['Make2'].value_counts()

# %%
df_co2.melt()
# Out:
#          variable value
# 0      Model_Year  2021
# 1      Model_Year  2021
# 2      Model_Year  2021
# 3      Model_Year  2021
# 4      Model_Year  2021
# ...           ...   ...
# 11215  Smog_Level     5
# 11216  Smog_Level     5
# 11217  Smog_Level     7
# 11218  Smog_Level     5
# 11219  Smog_Level     7
#
# [11220 rows x 2 columns]

# %%
df_co2.isnull().sum()
# Out:
# Model_Year                                0
# Make                                      0
# Model                                     0
# Vehicle_Class                             0
# Engine_Size                               0
# Cylinders                                 0
# Transmission                              0
# Fuel_Consumption_in_City(L/100 km)        0
# Fuel_Consumption_in_City_Hwy(L/100 km)    0
# Fuel_Consumption_comb(L/100km)            0
# CO2_Emissions                             0
# Smog_Level                                0
# dtype: int64

# %%
df_co2['Make'].value_counts().dropna(axis=1)
df_co2.drop('Model')
df_co2.fillna('ffil')

df_co2['Make'].value_counts()

# %%
def mfuc(x):
    if x=='Ford':
        print ('ff')
    elif x=='Chevrolet':
        print ('cc')
    elif x=='Porsche':
        print ('pp')
    elif x=='GMC ':
        print ('gm')
    elif x=='BMW':
        print ('bb')
    else:
        print ('ff')

# %%
df_co2=df_co2['Make'].apply(mfuc)
# Out:
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ff
# ...

# %%
df_co2
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 930    None
# 931    None
# 932    None
# 933    None
# 934    None
# Name: Make, Length: 935, dtype: object
